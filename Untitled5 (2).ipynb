# %% [markdown]
# # Project: Analysis of Euro 2024 [Uefa-Euro-2024-records]
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>
#
# <a id='intro'></a>
#
# ## Introduction
#
# ### Dataset Description
#
# This project involves a comprehensive analysis of three key datasets related to the Euro 2024 tournament: assists, goals, and matches. The primary objective is to explore these datasets to answer critical questions and extract valuable insights regarding the tournament's overall outcomes and individual player performances. By examining these aspects, the analysis provides a detailed overview of team strategies, player contributions, and notable trends observed throughout the competition.
#
# ## Objectives
#
# Before starting the analysis, it is essential to clean the datasets and check for any necessary modifications. After ensuring data quality, the following questions will be addressed:
#
# 1. **Determine the number of matches each team played to identify the teams in the final.**
# 2. **Calculate the total number of goals scored by each team.**
# 3. **Compare the number of shots per match for each team in the final and their goals scored per match.**
# 4. **Determine if the winning team had the top scorer or top assister.**
# 5. **Compare total shots on target to total scored goals for all teams.**
# 6. **Compare the number of top assisters and goal scorers to the number of matches their teams played.**
# 7. **Analyze total shots compared to total goals for each team.**
# 8. **Compare the performance of the top 5 teams in terms of goals, assists, and shots.**
# 9. **Calculate the average number of goals scored per match in the tournament.**
# 10. **Analyze total goals compared to total shots in the tournament.**ment**.

# %% [markdown]
# <a id='wrangling'></a>
# # Data Wrangling
#
# In this section, I undertook several essential data preparation steps to ensure the integrity and usability of the datasets. The process included cleaning and transforming the data to facilitate accurate and meaningful analysis. The primary steps were as follows:
#
# Spelling Mistakes
#
# Handling Missing Values:
#
#
# Data Type Corrections:
#
#
# Removing Duplicates:
#
#
# Initial Data Exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
#  ## this dataset is for the matches played in the whole tournemnt with the full states of each team

# %%
df = pd.read_csv('C:/Users/mogha/Downloads/archive (16)/matches.csv')
df.head()
# Out:
#    match_number    team1        team2 date_of_match                stadium  \
# 0             1  Germany     Scotland    15-06-2024    Fuball Arena Mnchen
# 1             2  Hungary  Switzerland    15-06-2024        Cologne Stadium
# 2             3    Spain      Croatia    15-06-2024  Olympiastadion Berlin
# 3             4    Italy      Albania    16-06-2024   BVB Stadion Dortmund
# 4             5   Poland  Netherlands    16-06-2024       Volksparkstadion
#
#    team1_goals  team2_goals audience  team1_total_shots  \
# 0            5            1   65,052                 20
# 1            1            3   41,676                  6
# 2            3            0   68,844                 11
# 3            2            1   60,512                 17
# 4            1            2   48,117                 12
#
#    team1_shots_on_target  ...  team2_offsides  team2_yellow_cards  \
# 0                     10  ...               0                   1
# ...

# %% [markdown]
# ##  this dataset is for the top assists

# %%
df1 = pd.read_csv('C:/Users/mogha/Downloads/archive (16)/assists.csv')
df1.head()
# Out:
#                         Player         Team  Assists
# 0  Lamine Yamal Nasraqui Ebana        Spain        4
# 1                   Arda Guler      Turkiye        2
# 2             Michel Aebischer  Switzerland        2
# 3               Joshua Kimmich      Germany        2
# 4                   Nathan Ake  Netherlands        2

# %% [markdown]
# ## this dataset is for the top goals

# %%
df2 = pd.read_csv('C:/Users/mogha/Downloads/archive (16)/goals.csv')
df2.head()
# Out:
#                Player     Team   Goals
# 0          Harry Kane   England      3
# 1        Ivan Schranz  Slovakia      3
# 2  Georges Mikautadze   Georgia      3
# 3           Dani Olmo     Spain      3
# 4       Jamal Musiala   Germany      3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 48 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   match_number               51 non-null     int64
#  1   team1                      51 non-null     object
#  2   team2                      51 non-null     object
#  3   date_of_match              51 non-null     object
#  4   stadium                    51 non-null     object
#  5   team1_goals                51 non-null     int64
#  6   team2_goals                51 non-null     int64
#  7   audience                   51 non-null     object
#  8   team1_total_shots          51 non-null     int64
#  9   team1_shots_on_target      51 non-null     int64
#  10  team2_total_shots          51 non-null     int64
#  11  team2_shots_on_target      51 non-null     int64
#  12  team1_fouls                51 non-null     int64
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Player   10 non-null     object
#  1   Team     10 non-null     object
#  2   Assists  10 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 372.0+ bytes

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  16 non-null     object
#  1   Team    16 non-null     object
#  2   Goals   16 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 516.0+ bytes

# %%
df. describe()
# Out:
#        match_number  team1_goals  team2_goals  team1_total_shots  \
# count     51.000000    51.000000    51.000000          51.000000
# mean      26.000000     1.274510     1.019608          13.372549
# std       14.866069     1.096876     0.905322           6.059574
# min        1.000000     0.000000     0.000000           4.000000
# 25%       13.500000     0.500000     0.000000           9.500000
# 50%       26.000000     1.000000     1.000000          13.000000
# 75%       38.500000     2.000000     1.000000          17.500000
# max       51.000000     5.000000     3.000000          35.000000
#
#        team1_shots_on_target  team2_total_shots  team2_shots_on_target  \
# count              51.000000          51.000000              51.000000
# mean                4.725490          12.352941               3.745098
# std                 2.764622           5.516606               2.161880
# min                 0.000000           1.000000               0.000000
# ...

# %%
df1.describe()
# Out:
#          Assists
# count  10.000000
# mean    2.200000
# std     0.632456
# min     2.000000
# 25%     2.000000
# 50%     2.000000
# 75%     2.000000
# max     4.000000

# %%
df2.describe()
# Out:
#         Goals
# count  16.000
# mean    2.375
# std     0.500
# min     2.000
# 25%     2.000
# 50%     2.000
# 75%     3.000
# max     3.000

# %%
print(df.isnull().sum())
# Out:
# match_number                 0
# team1                        0
# team2                        0
# date_of_match                0
# stadium                      0
# team1_goals                  0
# team2_goals                  0
# audience                     0
# team1_total_shots            0
# team1_shots_on_target        0
# team2_total_shots            0
# team2_shots_on_target        0
# team1_fouls                  0
# team1_corners                0
# team1_blocked_shots          0
# team1_passes                 0
# team1_accurate_passes        0
# team1_accurate_long_balls    0
# team1_accurate_crosses       0
# team1_throws                 0
# team1_offsides               0
# team1_yellowcards            0
# team1_red_cards              0
# team1_tackles_won            0
# team1_interceptions          0
# team1_blocks                 0
# team1_clearances             0
# team1_keeper_saves           0
# team1_duels_won              0
# team1_successful_dribbles    0
# ...

# %%
print(df1.isnull().sum())
# Out:
# Player     0
# Team       0
# Assists    0
# dtype: int64

# %%
print(df2.isnull().sum())
# Out:
# Player    0
# Team      0
# Goals     0
# dtype: int64

# %%
mask = df.query('team2_goals == 1')
mask
# Out:
#     match_number        team1        team2 date_of_match  \
# 0              1      Germany     Scotland    15-06-2024
# 3              4        Italy      Albania    16-06-2024
# 5              6     Slovenia      Denmark    16-06-2024
# 6              7       Serbia      England    17-06-2024
# 8              9      Belgium     Slovakia    17-06-2024
# 9             10      Austria       France    18-06-2024
# 10            11      Turkiye      Georgia    18-06-2024
# 11            12     Portugal      Czechia    19-06-2024
# 14            15     Scotland  Switzerland    20-06-2024
# 15            16     Slovenia       Serbia    20-06-2024
# 16            17      Denmark      England    20-06-2024
# 21            22      Georgia      Czechia    22-06-2024
# 24            25     Scotland      Hungary    24-06-2024
# 25            26  Switzerland      Germany    24-06-2024
# 26            27      Albania        Spain    25-06-2024
# ...

# %% [markdown]
#  ## i here found some spelling mistakes so i fixed them

# %%
df['stadium'].replace({'Dsseldorf Arena': 'Dusseldorf Arena'}, inplace=True)
df['stadium'].replace({'BVB Stadion Dortmund': 'BVB Stadium Dortmund'}, inplace=True)
df['stadium'].replace({'Fuball Arena Mnchen': 'Fuball Arena Munich'}, inplace=True)
df.head()
# Out:
#    match_number    team1        team2 date_of_match                stadium  \
# 0             1  Germany     Scotland    15-06-2024    Fuball Arena Munich
# 1             2  Hungary  Switzerland    15-06-2024        Cologne Stadium
# 2             3    Spain      Croatia    15-06-2024  Olympiastadion Berlin
# 3             4    Italy      Albania    16-06-2024   BVB Stadium Dortmund
# 4             5   Poland  Netherlands    16-06-2024       Volksparkstadion
#
#    team1_goals  team2_goals audience  team1_total_shots  \
# 0            5            1   65,052                 20
# 1            1            3   41,676                  6
# 2            3            0   68,844                 11
# 3            2            1   60,512                 17
# 4            1            2   48,117                 12
#
#    team1_shots_on_target  ...  team2_offsides  team2_yellow_cards  \
# 0                     10  ...               0                   1
# ...

# %% [markdown]
# ## i droped here some columns that are not important for me

# %%
df.drop(['team2_duels_won','match_number','team2_successful_dribbles'],axis = 1 , inplace = True)
df.head()
# Out:
#      team1        team2 date_of_match                stadium  team1_goals  \
# 0  Germany     Scotland    15-06-2024    Fuball Arena Munich            5
# 1  Hungary  Switzerland    15-06-2024        Cologne Stadium            1
# 2    Spain      Croatia    15-06-2024  Olympiastadion Berlin            3
# 3    Italy      Albania    16-06-2024   BVB Stadium Dortmund            2
# 4   Poland  Netherlands    16-06-2024       Volksparkstadion            1
#
#    team2_goals audience  team1_total_shots  team1_shots_on_target  \
# 0            1   65,052                 20                     10
# 1            3   41,676                  6                      2
# 2            0   68,844                 11                      5
# 3            1   60,512                 17                      5
# 4            2   48,117                 12                      7
#
#    team2_total_shots  ...  team2_accurate_crosses  team2_throws  \
# ...

# %%
mask = df.query('team2_goals == 1')
mask
# Out:
#           team1        team2 date_of_match                stadium  \
# 0       Germany     Scotland    15-06-2024    Fuball Arena Munich
# 3         Italy      Albania    16-06-2024   BVB Stadium Dortmund
# 5      Slovenia      Denmark    16-06-2024        Stuttgart Arena
# 6        Serbia      England    17-06-2024       Arena AufSchalke
# 8       Belgium     Slovakia    17-06-2024        Frankfurt Arena
# 9       Austria       France    18-06-2024       Dusseldorf Arena
# 10      Turkiye      Georgia    18-06-2024   BVB Stadium Dortmund
# 11     Portugal      Czechia    19-06-2024        Leipzig Stadium
# 14     Scotland  Switzerland    20-06-2024        Cologne Stadium
# 15     Slovenia       Serbia    20-06-2024    Fuball Arena Munich
# 16      Denmark      England    20-06-2024        Frankfurt Arena
# 21      Georgia      Czechia    22-06-2024       Volksparkstadion
# 24     Scotland      Hungary    24-06-2024        Stuttgart Arena
# ...

# %%
df['team1'].nunique()
# Out:
# 24

# %%
df.nunique()
# Out:
# team1                        24
# team2                        24
# date_of_match                24
# stadium                      10
# team1_goals                   6
# team2_goals                   4
# audience                     47
# team1_total_shots            20
# team1_shots_on_target        12
# team2_total_shots            19
# team2_shots_on_target        10
# team1_fouls                  14
# team1_corners                12
# team1_blocked_shots          10
# team1_passes                 46
# team1_accurate_passes        26
# team1_accurate_long_balls    48
# team1_accurate_crosses       43
# team1_throws                 18
# team1_offsides                6
# team1_yellowcards             7
# team1_red_cards               3
# team1_tackles_won            37
# team1_interceptions          15
# team1_blocks                  9
# team1_clearances             28
# team1_keeper_saves            8
# team1_duels_won              32
# team1_successful_dribbles    46
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# dtype: bool

# %%
df.drop(['team2_yellow_cards','team2_throws','team1_throws','team1_offsides','team2_offsides','team1_yellowcards','team1_duels_won'],axis = 1 , inplace = True)
df.head()
# Out:
#      team1        team2 date_of_match                stadium  team1_goals  \
# 0  Germany     Scotland    15-06-2024    Fuball Arena Munich            5
# 1  Hungary  Switzerland    15-06-2024        Cologne Stadium            1
# 2    Spain      Croatia    15-06-2024  Olympiastadion Berlin            3
# 3    Italy      Albania    16-06-2024   BVB Stadium Dortmund            2
# 4   Poland  Netherlands    16-06-2024       Volksparkstadion            1
#
#    team2_goals audience  team1_total_shots  team1_shots_on_target  \
# 0            1   65,052                 20                     10
# 1            3   41,676                  6                      2
# 2            0   68,844                 11                      5
# 3            1   60,512                 17                      5
# 4            2   48,117                 12                      7
#
#    team2_total_shots  ...  team2_blocked_shots  team2_passes  \
# ...

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
# The Exploratory Data Analysis (EDA) phase involved a comprehensive examination of the datasets to uncover patterns, relationships, and key insights. This phase is crucial for understanding the underlying structure of the data and setting the stage for further analysis

# %%
df.hist(figsize= (20,16));

# %%
df.hist(figsize=(20,12));

# %% [markdown]
# ## here i want to see the total number of matches each team played in order to see who was playing in the final
# ### the two teams with the most played games are the teams in the final

# %%
team1_counts = df['team1'].value_counts()
team2_counts = df['team2'].value_counts()
total_matches = team1_counts.add(team2_counts, fill_value=0).astype(int)
Teams = pd.concat([df['team1'], df['team2']])
total_matches_df = total_matches.reset_index()
total_matches_df.columns = ['Teams', 'Matches']
plt.figure(figsize=(26, 7))
plt.bar(total_matches_df['Teams'], total_matches_df['Matches'], color='blue')
plt.title('Total Goals Scored by Each Team in Euro 2024')
plt.xlabel('Teams')
plt.ylabel('Matches')
plt.show()

# %% [markdown]
# ## This graph indicates the total goals scored by each team in the tournument

# %%
team1_goals = df.groupby('team1')['team1_goals'].sum()
team2_goals = df.groupby('team2')['team2_goals'].sum()
total_goals = team1_goals.add(team2_goals, fill_value=0).astype(int)
total_goals_df = total_goals.reset_index()
total_goals_df.columns = ['Team', 'Goals_Scored']
teams = pd.concat([df['team1'], df['team2']])
plt.figure(figsize=(26, 7))
plt.bar(total_goals_df['Team'], total_goals_df['Goals_Scored'], color='blue')
plt.title('Total Goals Scored by Each Team in Euro 2024')
plt.xlabel('Team')
plt.ylabel('Goals Scored')
plt.show()

# %% [markdown]
# ## this graph comapres between every team's total shot to scored goals.

# %%
team1_goals = df.groupby('team1')['team1_goals'].sum()
team2_goals = df.groupby('team2')['team2_goals'].sum()
total_goals = team1_goals.add(team2_goals, fill_value=0).astype(int)
team1_shots = df.groupby('team1')['team1_total_shots'].sum()
team2_shots = df.groupby('team2')['team2_total_shots'].sum()
total_shots = team1_shots.add(team2_shots, fill_value=0).astype(int)
total_goals_df = total_goals.reset_index()
total_goals_df.columns = ['Team', 'Goals_Scored']
total_shots_df = total_shots.reset_index()
total_shots_df.columns = ['Team', 'Shots_Taken']
# Merge the dataframes on 'Team'
comparison_df = pd.merge(total_goals_df, total_shots_df, on='Team')
# Plot the data using matplotlib
plt.figure(figsize=(28, 10))
# Plot goals scored
plt.bar(comparison_df['Team'], comparison_df['Goals_Scored'], color='blue', alpha=0.6, label='Goals Scored')
# Plot shots taken
plt.bar(comparison_df['Team'], comparison_df['Shots_Taken'], color='grey', alpha=0.6, label='total shots', bottom=comparison_df['Goals_Scored'])
plt.title('Total Goals Scored vs. Total Shots Taken by Each Team in Euro 2024')
plt.xlabel('Team')
plt.ylabel('Total')
plt.legend()
plt.show()

# %% [markdown]
# ## total shots on target compared to  total goals for each team

# %%
team1_goals = df.groupby('team1')['team1_goals'].sum()
team2_goals = df.groupby('team2')['team2_goals'].sum()
total_goals = team1_goals.add(team2_goals, fill_value=0).astype(int)
team1_total_shots_on_target = df.groupby('team1')['team1_shots_on_target'].sum()
team2_total_shots_on_target = df.groupby('team2')['team2_shots_on_target'].sum()
total_shots_on_target = team1_total_shots_on_target.add(team2_total_shots_on_target, fill_value=0).astype(int)
total_goals_df = total_goals.reset_index()
total_goals_df.columns = ['Team', 'Goals_Scored']
total_shots_on_target_df = total_shots_on_target.reset_index()
total_shots_on_target_df.columns = ['Team', 'total_shots_on_target']
# Merge the dataframes on 'Team'
comparison_df = pd.merge(total_goals_df, total_shots_on_target_df, on='Team')
# Plot the data using matplotlib
plt.figure(figsize=(28, 10))
# Plot goals scored
plt.bar(comparison_df['Team'], comparison_df['Goals_Scored'], color='blue', alpha=0.6, label='Goals Scored')
# Plot shots taken
plt.bar(comparison_df['Team'], comparison_df['total_shots_on_target'], color='grey', alpha=0.6, label='total_shots_on_target', bottom=comparison_df['Goals_Scored'])
plt.title('Total Goals Scored vs. Total Shots on Target Taken by Each Team in Euro 2024')
plt.xlabel('Team')
plt.ylabel('Total')
plt.legend()
plt.show()

# %% [markdown]
# ## in this graph i wanted to see the percentage of total goals compared to the total shots taken in the tornument

# %%
team1_goals = df.groupby('team1')['team1_goals'].sum()
team2_goals = df.groupby('team2')['team2_goals'].sum()
total_goals = team1_goals.add(team2_goals, fill_value=0).astype(int).sum()

# Calculate total shots for each team
team1_total_shots = df.groupby('team1')['team1_total_shots'].sum()
team2_total_shots = df.groupby('team2')['team2_total_shots'].sum()
total_shots = team1_total_shots.add(team2_total_shots, fill_value=0).astype(int).sum()

# Create a pie chart
labels = ['Total Goals Scored', 'Total Shots Taken']
sizes = [total_goals, total_shots]
colors = ['blue', 'orange']
explode = (0.1, 0)  # explode the 1st slice (Total Goals Scored

plt.figure(figsize=(6, 7))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=180)
plt.title('Total Goals Scored vs. Total Shots Taken in Euro 2024')
plt.legend();
plt.show()

# %% [markdown]
#  ## here i wanted to see the total goals and and avergae goal per match to  decide if its high or normal or low

# %%
team1_goals = df['team1_goals'].sum()
team2_goals = df['team2_goals'].sum()
total_goals = team1_goals + team2_goals

# Calculate the total number of matches played
total_matches = df.shape[0]

# Calculate the average number of goals scored per match
average_goals_per_match = total_goals / total_matches

# Create a DataFrame for visualization
visualization_df = pd.DataFrame({
    'Metric': ['Total Goals', 'Average Goals per Match'],
    'Value': [total_goals, average_goals_per_match]
})

# Plot the data using matplotlib
plt.figure(figsize=(10, 6))
plt.plot(visualization_df['Metric'], visualization_df['Value'], marker='o', linestyle='-', color='blue')
plt.title('Total Goals and Average Goals per Match in Euro 2024')
plt.xlabel('Metric')
plt.ylabel('Value')
plt.ylim(0, max(visualization_df['Value']) + 10)
plt.yticks(range(0, int(max(visualization_df['Value'])) + 5,5))
plt.show()

# %%
# Calculate total goals scored by Spain
spain_goals_team1 = df[df['team1'] == 'Spain']['team1_goals'].sum()
spain_goals_team2 = df[df['team2'] == 'Spain']['team2_goals'].sum()
total_goals_spain = spain_goals_team1 + spain_goals_team2
#print(f"Total goals scored by Spain: {total_goals_spain}")

# Calculate total assists by Lamine Yamal
lamine_yamal_assists = df1[df1['Player'] == 'Lamine Yamal Nasraqui Ebana']['Assists'].sum()

#print(f"Total assists by Lamine Yamal: {lamine_yamal_assists}")

# Data for visualization
labels = ['Goals Assisted by Lamine Yamal', 'Other Goals']
sizes = [lamine_yamal_assists, total_goals_spain - lamine_yamal_assists]
colors = ['blue', 'grey']
explode = (0.1, 0)  # explode the 1st slice

# Plotting the pie chart
plt.figure(figsize=(6, 5))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=140)
plt.title('Contribution of Lamine Yamal to Total Goals Scored by Spain in Euro 2024')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Calculate total goals scored by Spain
England_goals_team1 = df[df['team1'] == 'England']['team1_goals'].sum()
England_goals_team2 = df[df['team2'] == 'England']['team2_goals'].sum()
total_goals_England = England_goals_team1 + England_goals_team2

Harry_kane_goals = df2[df2['Player'] == 'Harry Kane']['Goals'].sum()
print(f"TotalGoals by Harry Kane: {Harry_kane_goals}")
# Data for visualization
labels = ['Goals Scored by Harry Kane', 'Other Goals']
sizes = [Harry_kane_goals, total_goals_England - Harry_kane_goals]
colors = ['blue', 'grey']
explode = (0.1, 0)  # explode the 1st slice

# Plotting the pie chart
plt.figure(figsize=(6, 5))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=90)
plt.title('Contribution of Harry Kane to Total Goals Scored by England in Euro 2024')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# TotalGoals by Harry Kane: 3

# %% [markdown]
# ## here i wanted to compare between the pecrentage of top scorers to the number of total goals in the tournmemnt

# %%
team1_goals = df['team1_goals'].sum()
team2_goals = df['team2_goals'].sum()
total_goals_all_teams = team1_goals + team2_goals

print(f"Total goals scored by all teams: {total_goals_all_teams}")

# Calculate total goals scored by each player
total_goals_by_players = df2.groupby('Player')['Goals'].sum()

# Prepare data for visualization
players = total_goals_by_players.index.tolist()
goals = total_goals_by_players.tolist()
other_goals = total_goals_all_teams - sum(goals)

# Add 'Other Goals' to the list
players.append('Other Goals')
goals.append(other_goals)

# Plotting the pie chart
plt.figure(figsize=(10, 7))
plt.pie(goals, labels=players, autopct='%1.1f%%', startangle=140, colors=plt.cm.tab20.colors)
plt.title('Percentage of Goals Scored by Top Scorer Players to Total Goals Scored by All Teams in Euro 2024')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# Total goals scored by all teams: 117

# %% [markdown]
# ## i wanted to see here percentage of of top assisters compared to the total assists in the dataset

# %%
# team1_goals = df['team1_goals'].sum()
# team2_goals = df['team2_goals'].sum()
# total_goals_all_teams = team1_goals + team2_goals

# # Calculate total goals scored by each player
# total_assists_by_players = df1.groupby('Player')['Assists'].sum()

# # Prepare data for visualization
# players = total_assists_by_players.index.tolist()
# assists = total_assists_by_players.tolist()
# other_assists = total_goals_all_teams - sum(goals)

# # Add 'Other Goals' to the list
# players.append('Other Goals')
# goals.append(other_goals)

# # Plotting the pie chart
# plt.figure(figsize=(10, 7))
# plt.pie(goals, labels=players, autopct='%1.1f%%', startangle=140, colors=plt.cm.tab20.colors)
# plt.title('Percentage of Goals Assists by Players to Total Goals Scored by All Teams in Euro 2024')
# plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
# plt.show()
total_assists_by_players = df1.groupby('Player')['Assists'].sum()

# Calculate total assists
total_assists_all = total_assists_by_players.sum()

print(f"Total assists recorded: {total_assists_all}")

# Prepare data for visualization
players = total_assists_by_players.index.tolist()
assists = total_assists_by_players.tolist()
other_assists = total_assists_all - sum(assists)

# Add 'Other Assists' to the list


# Plotting the pie chart
plt.figure(figsize=(5, 7))
plt.pie(assists, labels=players, autopct='%1.1f%%', startangle=140, colors=plt.cm.tab20.colors)
plt.title('Percentage of Assists by Players to Total Assists in Euro 2024')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# Total assists recorded: 22

# %% [markdown]
# ## now i want to see the states of the winning team . so i decided to see the total goals scored compared to total goals conceded

# %%
spain_goals_team1 = df[df['team1'] == 'Spain']['team1_goals'].sum()
spain_goals_team2 = df[df['team2'] == 'Spain']['team2_goals'].sum()
total_goals_scored_spain = spain_goals_team1 + spain_goals_team2


# Calculate total goals conceded by Spain
spain_goals_conceded_as_team1 = df[df['team1'] == 'Spain']['team2_goals'].sum()
spain_goals_conceded_as_team2 = df[df['team2'] == 'Spain']['team1_goals'].sum()
total_goals_conceded_spain = spain_goals_conceded_as_team1 + spain_goals_conceded_as_team2


# Data for visualization
labels = ['Goals Scored by Spain', 'Goals Conceded by Spain']
sizes = [total_goals_scored_spain, total_goals_conceded_spain]
colors = ['blue', 'red']

# Plotting the bar chart
plt.figure(figsize=(10, 7))
plt.bar(labels, sizes, color=colors)
plt.title('Total Goals Scored vs. Total Goals Conceded by Spain in Euro 2024')
plt.xlabel('Category')
plt.ylabel('Number of Goals')
plt.show()

# Plotting the pie chart
# plt.figure(figsize=(10, 7))
# plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
# plt.title('Total Goals Scored vs. Total Goals Conceded by Spain in Euro 2024')
# plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
# plt.show()

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
